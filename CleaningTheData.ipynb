# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data= pd.read_csv(r'D:\Training_Data\FoodProject\sample_zomato2.csv')

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'url', 'address', 'name', 'online_order', 'book_table',
#        'rate', 'votes', 'phone', 'location', 'rest_type', 'dish_liked',
#        'cuisines', 'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
data.drop(['Unnamed: 0','dish_liked'],axis=1,inplace=True)

# %%
data.isna().sum()
# Out:
# url                              0
# address                          0
# name                             0
# online_order                     0
# book_table                       0
# rate                           134
# votes                            0
# phone                           18
# location                         0
# rest_type                        3
# cuisines                         3
# approx_cost(for two people)      0
# reviews_list                     0
# menu_item                        0
# listed_in(type)                  0
# listed_in(city)                  0
# dtype: int64

# %%
data.dropna(inplace=True)
print(len(data.index))
data.isna().sum()
# Out:
# 1291
# url                            0
# address                        0
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# phone                          0
# location                       0
# rest_type                      0
# cuisines                       0
# approx_cost(for two people)    0
# reviews_list                   0
# menu_item                      0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %%
data.reset_index(inplace=True)
data.head()
# Out:
#    index                                                url  \
# 0      0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1      1  https://www.zomato.com/bangalore/spice-elephan...
# 2      2  https://www.zomato.com/SanchurroBangalore?cont...
# 3      3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4      4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# ...

# %%
data.drop('index',inplace=True, axis=1)

# %%
for i in data.columns:
    for j in range(len(data.index)):
        try:
            if(',' in data[i][j]):
                print(i)
                break
        except:
            break
# Out:
# address
# rest_type
# cuisines
# approx_cost(for two people)
# reviews_list
# menu_item

# %%
for j in range(len(data.index)):
    if(',' in data['address'][j]):
        print(data['address'][j])
# Out:
# 942, 21st Main Road, 2nd Stage, Banashankari, Bangalore
# 2nd Floor, 80 Feet Road, Near Big Bazaar, 6th Block, Kathriguppe, 3rd Stage, Banashankari, Bangalore
# 1112, Next to KIMS Medical College, 17th Cross, 2nd Stage, Banashankari, Bangalore
# 1st Floor, Annakuteera, 3rd Stage, Banashankari, Bangalore
# 10, 3rd Floor, Lakshmi Associates, Gandhi Bazaar Main Road, Above Reliance Trends, Basavanagudi, Bangalore
# 37, 5-1, 4th Floor, Bosco Court, Gandhi Bazaar Main Road, Basavanagudi, Bangalore
# 19/1, New Timberyard Layout, Beside Satellite Bus Stop, Mysore Road, Bangalore
# 2469, 3rd Floor, 24th Cross, Opposite BDA Complex, 2nd Stage, Banashankari, Bangalore
# 2470, 21 Main Road, 25th Cross, Banashankari, Bangalore
# 12,29 Near PES University Back Gate, D'Souza Nagar, Hosakerehalli, 3rd Stage, Banashankari, Bangalore
# 941, 3rd FLOOR, 21st Main, 22nd Cross, Banashankari 2nd stage, Opposite to BDA complex, Banashankari
# 6th Block, 3rd Stage, Banashankari, Bangalore
# ...

# %%
for i in ['address','rest_type','approx_cost(for two people)','cuisines','reviews_list','menu_item']:
    for j in range(len(data.index)):
        try:
            if(',' in data[i][j]):
                data[i][j]='/'.join(data[i][j].split(','))
        except:
            pass

# %%
data.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942/ 21st Main Road/ 2nd Stage/ Banashankari/ ...                  Jalsa
# 1  2nd Floor/ 80 Feet Road/ Near Big Bazaar/ 6th ...         Spice Elephant
# 2  1112/ Next to KIMS Medical College/ 17th Cross...        San Churro Cafe
# 3  1st Floor/ Annakuteera/ 3rd Stage/ Banashankar...  Addhuri Udupi Bhojana
# 4  10/ 3rd Floor/ Lakshmi Associates/ Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
data.columns=['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
       'phone', 'location', 'rest_type', 'cuisines',
       'approx_cost_for_two_people', 'reviews_list', 'menu_item',
       'listed_in_type', 'listed_in_city']

# %%
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'cuisines',
#        'approx_cost_for_two_people', 'reviews_list', 'menu_item',
#        'listed_in_type', 'listed_in_city'],
#       dtype='object')

# %%
data.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942/ 21st Main Road/ 2nd Stage/ Banashankari/ ...                  Jalsa
# 1  2nd Floor/ 80 Feet Road/ Near Big Bazaar/ 6th ...         Spice Elephant
# 2  1112/ Next to KIMS Medical College/ 17th Cross...        San Churro Cafe
# 3  1st Floor/ Annakuteera/ 3rd Stage/ Banashankar...  Addhuri Udupi Bhojana
# 4  10/ 3rd Floor/ Lakshmi Associates/ Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
for j in range(len(data.index)):
    index=0
    for i in range(len(data['reviews_list'][j])):
        if(data['reviews_list'][j][i]==')'):
            index=i
            break
    data['reviews_list'][j] = data['reviews_list'][j][3:index-1]
    data['reviews_list'][j] = '-'.join(data['reviews_list'][j].split('\\n'))

# %%
data.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942/ 21st Main Road/ 2nd Stage/ Banashankari/ ...                  Jalsa
# 1  2nd Floor/ 80 Feet Road/ Near Big Bazaar/ 6th ...         Spice Elephant
# 2  1112/ Next to KIMS Medical College/ 17th Cross...        San Churro Cafe
# 3  1st Floor/ Annakuteera/ 3rd Stage/ Banashankar...  Addhuri Udupi Bhojana
# 4  10/ 3rd Floor/ Lakshmi Associates/ Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
for i in range(max(data.index)):
    if(data['menu_item'][i]=='[]'):
        data['menu_item'][i]='notAvailable'

# %%
data.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942/ 21st Main Road/ 2nd Stage/ Banashankari/ ...                  Jalsa
# 1  2nd Floor/ 80 Feet Road/ Near Big Bazaar/ 6th ...         Spice Elephant
# 2  1112/ Next to KIMS Medical College/ 17th Cross...        San Churro Cafe
# 3  1st Floor/ Annakuteera/ 3rd Stage/ Banashankar...  Addhuri Udupi Bhojana
# 4  10/ 3rd Floor/ Lakshmi Associates/ Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
for i in range(max(data.index)):
    data['rate'][i]=data['rate'][i][:-2]

# %%
for i in range(data.index[-1]):
    if('\n' in data['phone'][i]):
        data['phone'][i]=' and '.join(data['phone'][i].split('\n'))
    if('\r' in data['phone'][i]):
        data['phone'][i]=' and '.join(data['phone'][i].split('\r'))

# %%
data.address
# Out:
# 0       942/ 21st Main Road/ 2nd Stage/ Banashankari/ ...
# 1       2nd Floor/ 80 Feet Road/ Near Big Bazaar/ 6th ...
# 2       1112/ Next to KIMS Medical College/ 17th Cross...
# 3       1st Floor/ Annakuteera/ 3rd Stage/ Banashankar...
# 4       10/ 3rd Floor/ Lakshmi Associates/ Gandhi Baza...
#                               ...
# 1286    4/ 1st Cross/ Christ School Road/ Bhavani Layo...
# 1287    1274/ 2nd Cross/ 1st Block/ Opposite RMR Park/...
# 1288    172/1/ GF K 03/ Kiosk Unit/ Vega City Mall/ Sr...
# 1289    7/ 17th Cross Road/ Mahadeshwara Nagar/ Stage ...
# 1290    Shop 7/ 3 Floor/ Royal Minakshi Mall/ Bannergh...
# Name: address, Length: 1291, dtype: object

# %%
data.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942/ 21st Main Road/ 2nd Stage/ Banashankari/ ...                  Jalsa
# 1  2nd Floor/ 80 Feet Road/ Near Big Bazaar/ 6th ...         Spice Elephant
# 2  1112/ Next to KIMS Medical College/ 17th Cross...        San Churro Cafe
# 3  1st Floor/ Annakuteera/ 3rd Stage/ Banashankar...  Addhuri Udupi Bhojana
# 4  10/ 3rd Floor/ Lakshmi Associates/ Gandhi Baza...          Grand Village
#
#   online_order book_table rate  votes                                   phone  \
# 0          Yes        Yes  4.1    775    080 42297555 and  and +91 9743772233
# ...

# %%
for i in data.columns:
    for j in range(data.index[-1]):
        try:
            if('\n' in data[i][j]):
                print(daat[i][j])
            if('\r' in data[i][j]):
                print(daat[i][j])
        except:
            break

# %%
for i in range(data.index[-1]):
    if(data['rate'][i]=='N'):
        data['rate'][i]=0

# %%
for i in range(data.index[-1]):
    data['approx_cost_for_two_people'][i]=data['approx_cost_for_two_people'][i][-3:]

# %%
data['menu_item'][1290]='notAvailable'
data['rate'][1290]=data['rate'][1290][:-2]

# %%
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'cuisines',
#        'approx_cost_for_two_people', 'reviews_list', 'menu_item',
#        'listed_in_type', 'listed_in_city'],
#       dtype='object')

# %%
paymentMode=['GPay, PhonePe, Paytm','PhonePe, GPay, NetBanking','Paytm, GPay','NetBanking, CreditCard, DebitCard','CreditCard, Cash','CreditCard, DebitCard, Cash', 'Cash']
Discount= list(range(10,51,5))
Capacity= list(range(50,201,10))
cateringAvailable =['yes','no']

# %%
import random
payMode,percentDiscount, totalCapacity, Catering=[],[],[],[]
for i in range(len(data.index)):
    a,b,c,d= list(map(random.choice, [paymentMode, Discount, Capacity, cateringAvailable]))
    payMode.append(a)
    percentDiscount.append(b)
    totalCapacity.append(c)
    Catering.append(d)

# %%
data['payMode']=payMode
data['Discount']=percentDiscount
data['Capacity']=totalCapacity
data['Catering']=Catering

# %%
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'cuisines',
#        'approx_cost_for_two_people', 'reviews_list', 'menu_item',
#        'listed_in_type', 'listed_in_city', 'payMode', 'Discount', 'Capacity',
#        'Catering'],
#       dtype='object')

# %%
data.to_csv('cleanedData.csv', header=True, index=False)

# %%
data.online_order.isna().sum()
# Out:
# 0

# %%
pwd
# Out:
# 'C:\\Users\\sulem'
